# %%
import requests
import json
# from PIL import Image

# %%
trakt_api = '3f98923e2a8b7be3e0c6d32b2e8ac5a8cc02a0b037e6b402b80ce30695699b02'
tmdb_api = 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxZGJiYjQ4YTNhZDZkMjA1MzJhYzU3MzgwZDg0NWQyYSIsInN1YiI6IjY0OTk0NTZjYjM0NDA5MDBjNTRmZjgwOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.xJQzD2BiHM_QWdX5gQ23317aM9LdmkkomEchtoR3Lck'

trakt_headers = {
    'Content-Type': 'application/json',
    'trakt-api-version': '2',
    'trakt-api-key': trakt_api
}

tmdb_headers = {
    "accept": "application/json",
    "Authorization": tmdb_api
}

# overlord：97792
# bleach：30850
# house of dragon: 154574
# Secret Invasion: 170566

# %%
trakt_id = '170566'
trakt_api_url = f'https://api.trakt.tv/shows/Secret-Invasion?extended=full'
    
got = requests.get(trakt_api_url, headers=trakt_headers).json()

# %%
got
# Out:
# {'title': 'Secret Invasion',
#  'year': 2023,
#  'ids': {'trakt': 170566,
#   'slug': 'secret-invasion',
#   'tvdb': 393203,
#   'imdb': 'tt13157618',
#   'tmdb': 114472,
#   'tvrage': None},
#  'overview': 'Nick Fury and Talos discover a faction of shapeshifting Skrulls who have been infiltrating Earth for years.',
#  'first_aired': '2023-06-21T07:00:00.000Z',
#  'airs': {'day': 'Wednesday', 'time': '03:00', 'timezone': 'America/New_York'},
#  'runtime': 55,
#  'certification': 'TV-14',
#  'network': 'Disney+',
#  'country': 'us',
#  'trailer': 'https://youtube.com/watch?v=Tp_YZNqNBhw',
#  'homepage': 'https://www.disneyplus.com/series/secret-invasion/3iHQtD1BDpgN',
#  'status': 'returning series',
#  'rating': 6.93266,
#  'votes': 297,
#  'comment_count': 9,
#  'updated_at': '2023-07-05T18:39:27.000Z',
#  'language': 'en',
#  'available_translations': ['ar',
#   'bg',
#   'cs',
#   'de',
#   'el',
#   'en',
#   'es',
#   'fr',
#   'he',
#   'hu',
#   'it',
#   'ja',
#   'ka',
# ...

# %%
    
trakt_next_api_url = f'https://api.trakt.tv/shows/170566/last_episode?extended=full'
# trakt_next_api_url = 'https://api.trakt.tv/shows/154574/next_episode'
    
next_episode = requests.get(trakt_next_api_url, headers=trakt_headers).json()
# next_episode

# %%
def get_show_details_from_trakt(show_id):

    # URLs for Trakt API: Show Summary, Next Episode Info
    trakt_api_url = f'https://api.trakt.tv/shows/{show_id}?extended=full'
    trakt_api_next_episode_url = f'https://api.trakt.tv/shows/{show_id}/next_episode?extended=full'
    
    # Send a GET request to the Trakt API for show details
    response = requests.get(trakt_api_url, headers=trakt_headers)
    response.raise_for_status()
    show_details = response.json()

    # Try to get the next episode details
    response = requests.get(trakt_api_next_episode_url, headers=trakt_headers)
    
    if response.status_code == 200:  # If the next episode exists
        next_episode_details = response.json()

        show_details.update({
            'next_episode': {
                'season': next_episode_details.get('season'),
                'number': next_episode_details.get('number'),
                'first_aired': next_episode_details.get('first_aired'),
            }
        })
    elif response.status_code == 204:  # If the next episode does not exist
        show_details.update({
            'next_episode': None
        })

    return show_details

# %%
selected_show_data = get_show_details_from_trakt(170566)

# %%
selected_show_data
# Out:
# {'title': 'Secret Invasion',
#  'year': 2023,
#  'ids': {'trakt': 170566,
#   'slug': 'secret-invasion',
#   'tvdb': 393203,
#   'imdb': 'tt13157618',
#   'tmdb': 114472,
#   'tvrage': None},
#  'overview': 'Nick Fury and Talos discover a faction of shapeshifting Skrulls who have been infiltrating Earth for years.',
#  'first_aired': '2023-06-21T07:00:00.000Z',
#  'airs': {'day': 'Wednesday', 'time': '03:00', 'timezone': 'America/New_York'},
#  'runtime': 55,
#  'certification': 'TV-14',
#  'network': 'Disney+',
#  'country': 'us',
#  'trailer': 'https://youtube.com/watch?v=Tp_YZNqNBhw',
#  'homepage': 'https://www.disneyplus.com/series/secret-invasion/3iHQtD1BDpgN',
#  'status': 'returning series',
#  'rating': 6.92905,
#  'votes': 296,
#  'comment_count': 9,
#  'updated_at': '2023-07-05T18:39:27.000Z',
#  'language': 'en',
#  'available_translations': ['ar',
#   'bg',
#   'cs',
#   'de',
#   'el',
#   'en',
#   'es',
#   'fr',
#   'he',
#   'hu',
#   'it',
#   'ja',
#   'ka',
# ...

# %%
got['ids']['trakt']
# Out:
# 97792

# %%
popular = requests.get('https://api.trakt.tv/movies/popular', headers=trakt_headers).json()

# %%
trending = requests.get('https://api.trakt.tv/shows/trending', headers=trakt_headers).json()

# %%
summary = requests.get('https://api.trakt.tv/shows/30850', headers=trakt_headers).json()

# %%
searched_data = requests.get('https://api.trakt.tv/search/show?query=bleach', headers=trakt_headers).json()

# %%
summary
# Out:
# {'title': 'Bleach',
#  'year': 2004,
#  'ids': {'trakt': 30850,
#   'slug': 'bleach',
#   'tvdb': 74796,
#   'imdb': 'tt0434665',
#   'tmdb': 30984,
#   'tvrage': None}}

# %%
trakt_url = "https://api.trakt.tv/movies/popular"

popular_result = requests.get(trakt_url, headers=trakt_headers)

if popular_result.status_code == 200:
    # 提取电影信息
    movies = popular_result.json()
    for movie in movies:
        trakt_movie_id = movie["ids"]["tmdb"]
        tmdb_url = f"https://api.themoviedb.org/3/movie/{trakt_movie_id}?language=en-US"
        headers = {
            "accept": "application/json",
            "Authorization": tmdb_api
        }

        tmdb_data = requests.get(tmdb_url, headers=tmdb_headers)

        # 处理API响应
        if tmdb_data.status_code == 200:
            # 提取电影信息
            tmdb_data = tmdb_data.json()
            tmdb_movie_id = tmdb_data["id"]
            
            # 在这里，你可以使用TMDB电影ID来获取电影海报或其他信息
            tmdb_image_url = f"https://api.themoviedb.org/3/movie/{tmdb_movie_id}/images"
            tmdb_image_result = requests.get(tmdb_image_url, headers=tmdb_headers)
            if tmdb_image_result.status_code == 200:
                # 提取电影海报信息
                images_data = tmdb_image_result.json()
                posters = images_data["posters"]
                for poster in posters:
                    poster_path = poster["file_path"]
    
                    # 在这里，你可以处理电影海报的URL或下载电影海报
                    poster_url = 'https://image.tmdb.org/t/p/w500' + poster_path
                    print(poster_url)
#                     data = requests.get(poster_url).content
#                     f = open('img.jpg','wb')
#                     f.write(data)
#                     f.close()
            else:
                print("TMDB Image API请求失败")
        else:
            print("TMDB Data API请求失败")
else:
    print("Trakt API请求失败")
# Out:
# https://image.tmdb.org/t/p/w500/fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg
# https://image.tmdb.org/t/p/w500/3E53WEZJqP6aM84D8CckXx4pIHw.jpg
# https://image.tmdb.org/t/p/w500/z5VjcCEioj2c2dvxmoqBW0Rj8Xj.jpg
# https://image.tmdb.org/t/p/w500/zq8Cl3PNIDGU3iWNRoc5nEZ6pCe.jpg
# https://image.tmdb.org/t/p/w500/pcZT1Ouq99dY6J2iGXjMxw16x6o.jpg
# https://image.tmdb.org/t/p/w500/wWzGAWmdX7IL1mOYyhiYKso0FrI.jpg
# https://image.tmdb.org/t/p/w500/VEfCqkbK062Egob26rYQWAJoE7.jpg
# https://image.tmdb.org/t/p/w500/uNgSXu6iveo9WQABOhFb72QH0qr.jpg
# https://image.tmdb.org/t/p/w500/yGSxMiF0cYuAiyuve5DA6bnWEOI.jpg
# https://image.tmdb.org/t/p/w500/7vEAHaoSXU5evsHMTETUFRVW3QW.jpg
# https://image.tmdb.org/t/p/w500/3Oft5fKQr1KHUhzqbfLrw9MDhwD.jpg
# https://image.tmdb.org/t/p/w500/qPJC6cNMkHLJhcD52jKHh56Fzxa.jpg
# https://image.tmdb.org/t/p/w500/uoEvIHCpli8qfMHnFRG6QxJA4tm.jpg
# https://image.tmdb.org/t/p/w500/ts2v8Lho9LJYqvKK7z0FGQ1cLLU.jpg
# https://image.tmdb.org/t/p/w500/gBYgQQe5mmh8fIQTWRht8gzJV8G.jpg
# ...

# %%
# img = Image.open('img.jpg')
# img.show()

# %%
tmdb_show_id = 1429
trakt_show_id = 30850
tmdb_show_url = f'https://api.themoviedb.org/3/tv/{tmdb_show_id}'
response = requests.get(tmdb_show_url, headers=tmdb_headers)
tmdb_show_data = response.json()

# %%
tmdb_current_season_number = tmdb_show_data['last_episode_to_air']['season_number']

# Make the API request to retrieve the season details for the latest aired season
tmdb_season_url = f'https://api.themoviedb.org/3/tv/{tmdb_show_id}/season/{tmdb_current_season_number}'
tmdb_season_response = requests.get(tmdb_season_url, headers=tmdb_headers)
tmdb_season_data = tmdb_season_response.json()

# %%
tmdb_show_data
# Out:
# {'adult': False,
#  'backdrop_path': '/rqbCbjB19amtOtFQbb3K2lgm2zv.jpg',
#  'created_by': [],
#  'episode_run_time': [25],
#  'first_air_date': '2013-04-07',
#  'genres': [{'id': 10765, 'name': 'Sci-Fi & Fantasy'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 10759, 'name': 'Action & Adventure'}],
#  'homepage': 'https://shingeki.tv/',
#  'id': 1429,
#  'in_production': True,
#  'languages': ['ja'],
#  'last_air_date': '2022-04-04',
#  'last_episode_to_air': {'id': 3508327,
#   'name': 'The Dawn of Humanity',
#   'overview': "Regardless of where it all began, Eren commits to his path of destruction during the Scouts' first visit to the Marleyan mainland, leaving Mikasa to wonder if things could've been different.",
#   'vote_average': 8.563,
#   'vote_count': 16,
#   'air_date': '2022-04-04',
#   'episode_number': 28,
#   'production_code': '',
#   'runtime': 23,
#   'season_number': 4,
#   'show_id': 1429,
#   'still_path': '/qsOd2QmvWaP9eVZsRhgz4Gj87z9.jpg'},
# ...

# %%
trakt_show_url = f'https://api.trakt.tv/shows/{trakt_show_id}?extended=full'
response = requests.get(trakt_show_url, headers=trakt_headers)
trakt_show_data = response.json()

# %%
# trakt_show_data

# %%
next_ep_trakt_id = 30850
trakt_next_ep_url = f'https://api.trakt.tv/shows/{next_ep_trakt_id}/next_episode'
response = requests.get(trakt_next_ep_url, headers=trakt_headers)
trakt_next_ep_data = response.json()

# %%
trakt_next_ep_data
# Out:
# {'season': 2,
#  'number': 14,
#  'title': 'Episode 14',
#  'ids': {'trakt': 10708312,
#   'tvdb': None,
#   'imdb': None,
#   'tmdb': 4486962,
#   'tvrage': None}}

# %%
BASE_URL = "https://api.trakt.tv"
show_id = 138163
season_number = 2
url = f"{BASE_URL}/shows/{show_id}/seasons/{season_number}"

response = requests.get(url, headers=trakt_headers)
if response.status_code == 200:
    season_data = response.json()
    print(season_data)
else:
    print(f"Error: {response.status_code}")
# Out:
# [{'season': 2, 'number': 1, 'title': 'A Grain of Truth', 'ids': {'trakt': 5294193, 'tvdb': 8544198, 'imdb': 'tt11277244', 'tmdb': 3063744, 'tvrage': None}}, {'season': 2, 'number': 2, 'title': 'Kaer Morhen', 'ids': {'trakt': 5297661, 'tvdb': 8544480, 'imdb': 'tt11654982', 'tmdb': 3063820, 'tvrage': None}}, {'season': 2, 'number': 3, 'title': 'What Is Lost', 'ids': {'trakt': 5297662, 'tvdb': 8544481, 'imdb': 'tt11655000', 'tmdb': 3063821, 'tvrage': None}}, {'season': 2, 'number': 4, 'title': 'Redanian Intelligence', 'ids': {'trakt': 5297663, 'tvdb': 8544482, 'imdb': 'tt11655010', 'tmdb': 3063822, 'tvrage': None}}, {'season': 2, 'number': 5, 'title': 'Turn Your Back', 'ids': {'trakt': 5297664, 'tvdb': 8544483, 'imdb': 'tt11655020', 'tmdb': 3063823, 'tvrage': None}}, {'season': 2, 'number': 6, 'title': 'Dear Friend...', 'ids': {'trakt': 5297665, 'tvdb': 8544484, 'imdb': 'tt11655028', 'tmdb': 3063824, 'tvrage': None}}, {'season': 2, 'number': 7, 'title': 'Voleth Meir', 'ids': {'trakt': 5
# ...
